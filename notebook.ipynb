# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Agna Aldhaka Indra Alam
# - **Email:** m279d4ky1934@bangkit.academy
# - **ID Dicoding:** M279D4KY1934

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 : bagaimana perkembangan nilai air quality index berdasarkan tingkat polusi udara pada tahun 2013 sampai 2017
# - Pertanyaan 2 : bagaimana perkembangan air quality index setiap bulannya untuk mengetahui hubungan antara musim dengan tingkat polusi udara

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# memuat data tabel dan menampilkan sampel

# %%
aotizhongxin_df = pd.read_csv("data/PRSA_Data_Aotizhongxin_20130301-20170228.csv")
aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
changpin_df = pd.read_csv("data/PRSA_Data_Changping_20130301-20170228.csv")
changpin_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
dongsi_df = pd.read_csv("data/PRSA_Data_Dongsi_20130301-20170228.csv")
dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %% [markdown]
# ### Assessing Data

# %%
#melihat informasi data aotizhongxin
aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2_5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
#memeriksa jumlah missing value
aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2_5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
#memeriksa jumlah duplikasi
print("Jumlah duplikasi: ", aotizhongxin_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
#memeriksa parameter statistik
aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2_5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %% [markdown]
# * aotizhongxin memiliki beberapa missing value

# %%
#melihat informasi data changpin
changpin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2_5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
#melihat jumlah missing value
changpin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2_5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
#memeriksa jumlah duplikasi data
print("Jumlah duplikasi: ", changpin_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
#memeriksa parameter statistik
changpin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2_5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %% [markdown]
# * changpin memiliki beberapa missing value

# %%
#melihat informasi data dongsi
dongsi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2_5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
#memeriksa jumlah missing value
dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2_5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
#memeriksa data duplikate
print("Jumlah duplikasi: ", dongsi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
#memeriksa parameter statistik
dongsi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2_5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %% [markdown]
# * dongsi memiliki beberapa missing value

# %% [markdown]
# ### Cleaning Data

# %%
#menangani missing value PM2_5
#menampilkan data yang mengalami missing value
aotizhongxin_df[aotizhongxin_df.PM2_5.isna()]
# Out:
#           No  year  month  day  hour  PM2_5   PM10      SO2      NO2      CO  \
# 1509    1510  2013      5    2    21    NaN  183.0  63.0000  93.0000  1200.0
# 1837    1838  2013      5   16    13    NaN   98.0  46.0000  35.0000   600.0
# 2368    2369  2013      6    7    16    NaN  137.0  12.0000  74.0000  2500.0
# 2785    2786  2013      6   25     1    NaN   35.0   3.1416  35.1063     NaN
# 2808    2809  2013      6   26     0    NaN  183.0  64.2600  40.0335     NaN
# ...      ...   ...    ...  ...   ...    ...    ...      ...      ...     ...
# 34880  34881  2017      2   21     8    NaN    NaN      NaN      NaN     NaN
# 34883  34884  2017      2   21    11    NaN    NaN      NaN      NaN     NaN
# 34885  34886  2017      2   21    13    NaN    NaN      NaN      NaN     NaN
# 35028  35029  2017      2   27    12    NaN    NaN      NaN      NaN     NaN
# 35029  35030  2017      2   27    13    NaN    NaN      NaN      NaN     NaN
#
# ...

# %%
#mencari nilai mean dari pm2_5
aotizhongxin_mean = aotizhongxin_df.PM2_5.mean()

# %%
#mengganti missing value dengan mean dikarenakan data kontinyu
aotizhongxin_df.PM2_5.fillna(value= aotizhongxin_mean, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\3902149332.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aotizhongxin_df.PM2_5.fillna(value= aotizhongxin_mean, inplace=True)

# %%
#memeriksa
aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2_5         0
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
#menangani missing value PM10
#menampilkan data yang mengalami missing value
aotizhongxin_df[aotizhongxin_df.PM10.isna()]
# Out:
#           No  year  month  day  hour      PM2_5  PM10   SO2   NO2      CO  \
# 204      205  2013      3    9    12  78.000000   NaN  10.0  10.0   300.0
# 2949    2950  2013      7    1    21  85.000000   NaN  12.0  79.0  2100.0
# 3133    3134  2013      7    9    13  52.000000   NaN   6.0  50.0   700.0
# 4513    4514  2013      9    5     1  24.000000   NaN   1.0  35.0   400.0
# 4706    4707  2013      9   13     2  61.000000   NaN   2.0  35.0   500.0
# ...      ...   ...    ...  ...   ...        ...   ...   ...   ...     ...
# 34880  34881  2017      2   21     8  82.773611   NaN   NaN   NaN     NaN
# 34883  34884  2017      2   21    11  82.773611   NaN   NaN   NaN     NaN
# 34885  34886  2017      2   21    13  82.773611   NaN   NaN   NaN     NaN
# 35028  35029  2017      2   27    12  82.773611   NaN   NaN   NaN     NaN
# 35029  35030  2017      2   27    13  82.773611   NaN   NaN   NaN     NaN
#
#          O3  TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
#mencari nilai mean dari pm2_5
aotizhongxin_PM10_mean = aotizhongxin_df.PM10.mean()

# %%
#mengganti missing value dengan mean dikarenakan data kontinyu
aotizhongxin_df.PM10.fillna(value= aotizhongxin_PM10_mean, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\1984974397.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aotizhongxin_df.PM10.fillna(value= aotizhongxin_PM10_mean, inplace=True)

# %%
#memeriksa
aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2_5         0
# PM10          0
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
#mengganti missing value yang lain
aotizhongxin_df.SO2.fillna(value= aotizhongxin_df.SO2.mean(), inplace=True)
aotizhongxin_df.NO2.fillna(value= aotizhongxin_df.NO2.mean(), inplace=True)
aotizhongxin_df.CO.fillna(value= aotizhongxin_df.CO.mean(), inplace=True)
aotizhongxin_df.O3.fillna(value= aotizhongxin_df.O3.mean(), inplace=True)
aotizhongxin_df.TEMP.fillna(value= aotizhongxin_df.TEMP.mean(), inplace=True)
aotizhongxin_df.PRES.fillna(value= aotizhongxin_df.PRES.mean(), inplace=True)
aotizhongxin_df.DEWP.fillna(value= aotizhongxin_df.DEWP.mean(), inplace=True)
aotizhongxin_df.RAIN.fillna(value= aotizhongxin_df.RAIN.mean(), inplace=True)
aotizhongxin_df.WSPM.fillna(value= aotizhongxin_df.WSPM.mean(), inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\381968854.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aotizhongxin_df.SO2.fillna(value= aotizhongxin_df.SO2.mean(), inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\381968854.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#memeriksa
aotizhongxin_df.isna().sum()
# Out:
# No          0
# year        0
# month       0
# day         0
# hour        0
# PM2_5       0
# PM10        0
# SO2         0
# NO2         0
# CO          0
# O3          0
# TEMP        0
# PRES        0
# DEWP        0
# RAIN        0
# wd         81
# WSPM        0
# station     0
# dtype: int64

# %%
#mengganti kolom wd dengan nilai baris sebelumnya
aotizhongxin_df.wd.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\195003197.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aotizhongxin_df.wd.fillna(method='ffill', inplace=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\195003197.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   aotizhongxin_df.wd.fillna(method='ffill', inplace=True)

# %%
#memeriksa
aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2_5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# * mengisi missing value aotizhongsin menggunakan nilai mean, dan menggunakan nilai sebelumnya untuk data arah angin

# %%
#mengisi missing value data changpin
#memeriksa missing value
changpin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2_5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
#mengisi missing value dengan mean
changpin_df.PM2_5.fillna(value= changpin_df.PM2_5.mean(), inplace= True)
changpin_df.PM10.fillna(value= changpin_df.PM10.mean(), inplace=True)
changpin_df.SO2.fillna(value= changpin_df.SO2.mean(), inplace=True)
changpin_df.NO2.fillna(value= changpin_df.NO2.mean(), inplace=True)
changpin_df.CO.fillna(value= changpin_df.CO.mean(), inplace=True)
changpin_df.O3.fillna(value= changpin_df.O3.mean(), inplace=True)
changpin_df.TEMP.fillna(value= changpin_df.TEMP.mean(), inplace=True)
changpin_df.PRES.fillna(value= changpin_df.PRES.mean(), inplace=True)
changpin_df.DEWP.fillna(value= changpin_df.DEWP.mean(), inplace=True)
changpin_df.RAIN.fillna(value= changpin_df.RAIN.mean(), inplace=True)
changpin_df.WSPM.fillna(value= changpin_df.WSPM.mean(), inplace=True)
#mengisi missing value dengan nilai sebelumnya
changpin_df.wd.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\3354153183.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changpin_df.PM2_5.fillna(value= changpin_df.PM2_5.mean(), inplace= True)
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\3354153183.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#memeriksa
changpin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2_5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# *mengganti missing value pada data frame changpin dengan nilai mean dan juga nilai sebelumnya untuk arah angin

# %%
#mengisi missing value data dongsi
#memeriksa
dongsi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2_5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
#mengisi missing value dengan mean
dongsi_df.PM2_5.fillna(value= dongsi_df.PM2_5.mean(), inplace= True)
dongsi_df.PM10.fillna(value= dongsi_df.PM10.mean(), inplace=True)
dongsi_df.SO2.fillna(value= dongsi_df.SO2.mean(), inplace=True)
dongsi_df.NO2.fillna(value= dongsi_df.NO2.mean(), inplace=True)
dongsi_df.CO.fillna(value= dongsi_df.CO.mean(), inplace=True)
dongsi_df.O3.fillna(value= dongsi_df.O3.mean(), inplace=True)
dongsi_df.TEMP.fillna(value= dongsi_df.TEMP.mean(), inplace=True)
dongsi_df.PRES.fillna(value= dongsi_df.PRES.mean(), inplace=True)
dongsi_df.DEWP.fillna(value= dongsi_df.DEWP.mean(), inplace=True)
dongsi_df.RAIN.fillna(value= dongsi_df.RAIN.mean(), inplace=True)
dongsi_df.WSPM.fillna(value= dongsi_df.WSPM.mean(), inplace=True)
#mengisi missing value dengan nilai sebelumnya
dongsi_df.wd.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\577375015.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_df.PM2_5.fillna(value= dongsi_df.PM2_5.mean(), inplace= True)
# C:\Users\user\AppData\Local\Temp\ipykernel_14152\577375015.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
#memeriksa
dongsi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2_5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# * mengisi missing value untuk dataframe dongsi dengan nilai rata-rata dan nilai sebelumnya untuk arah angin

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
#menentukan nilai Air Quality Index
#mengubah berdasarkan pedoman dari EPA
#membuat tuple yang berisi : 2 nilai paling depan berisi nilai dari polutan
#2 nilai paling belakang berisi index AQI
PM2_5_breakpoints = [(0, 12, 0, 50), (13, 35, 51, 100), (36, 55, 101, 150), 
                     (56, 150, 151, 200), (151, 250, 201, 300), (251, 9999, 301, 500)]
PM10_breakpoints = [(0, 54, 0, 50), (55, 154, 51, 100), (155, 254, 101, 150), 
                     (255, 354, 151, 200), (355, 424, 201, 300), (425, 9999, 301, 500)]
SO2_breakpoints = [(0, 35, 0, 50), (36, 75, 51, 100), (76, 185, 101, 150), 
                     (186, 304, 151, 200), (305, 604, 201, 300), (605, 9999, 301, 500)]
NO2_breakpoints = [(0, 53, 0, 50), (54, 100, 51, 100), (101, 360, 101, 150), 
                     (361, 649, 151, 200), (650, 1249, 201, 300), (1250, 9999, 301, 500)]
CO_breakpoints = [(0, 4, 0, 50), (5, 9, 51, 100), (10, 12, 101, 150), 
                     (13, 15, 151, 200), (16, 30, 201, 300), (31, 9999, 301, 500)]
O3_breakpoints = [(0, 50, 0, 50), (51, 70, 51, 100), (71, 85, 101, 150),
                    (86, 105, 151, 200), (106, 205, 201, 300), (206, 999999, 301, 500)]

# %%
#fungsi untuk menentukan nilai aqi berdasarkan sub index
def calculate_sub_index(concentration, breakpoints):
    for (low_conc, high_conc, low_index, high_index) in breakpoints:
        if low_conc <= concentration <= high_conc:
            return low_index + (high_index - low_index) / (high_conc - low_conc) * (concentration - low_conc)
    # jika nilai sub index melebihi batas maka akan dikembalikan menjadi nilai tertinggi aqi
    return 500

# %%
# menghitung nilai AQI untuk setiap baris pada data set
def calculate_aqi(row):
   
    # mengubah nilai konsentrasi polutan menjadi sub index
    row['PM2_5_sub_index'] = calculate_sub_index(row['PM2_5'], PM2_5_breakpoints)
    row['PM10_sub_index'] = calculate_sub_index(row['PM10'], PM10_breakpoints)
    row['NO2_sub_index'] = calculate_sub_index(row['NO2'], NO2_breakpoints)
    row['O3_sub_index'] = calculate_sub_index(row['O3'], O3_breakpoints)
    row['CO_sub_index'] = calculate_sub_index(row['CO'] * 0.001, CO_breakpoints)  # mengubah µg/m³ menjadi mg/m³
    row['SO2_sub_index'] = calculate_sub_index(row['SO2'], SO2_breakpoints)
 

    # AQI merupakan nilai sub index tertinggi
    aqi = max(row['PM2_5_sub_index'], row['PM10_sub_index'], row['NO2_sub_index'],
              row['O3_sub_index'], row['CO_sub_index'], row['SO2_sub_index'])
    return aqi

# %% [markdown]
# panduan membuat kode pemrogaman untuk menghitung aqi didapat dari [https://medium.com](/dare-to-be-better/case-study-4-a-step-by-step-guide-to-analyzing-the-aqi-air-quality-index-778c14b0dcfc) dan disesuaikan menggunakan pedoman penulisan dari EPA [https://www.airnow.gov](/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf)

# %%
#memasukkan kedalam dataframe aotizhongxin
aotizhongxin_df['AQI'] = aotizhongxin_df.apply(calculate_aqi, axis=1)
aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station    AQI
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin  122.0
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin  122.0
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin  108.0
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin  104.5
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin  104.5

# %%
#memasukkan kedalam dataframe achangpin
changpin_df['AQI'] = changpin_df.apply(calculate_aqi, axis=1)
changpin_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station    AQI
# 0  1020.8 -19.7   0.0    E   0.5  Changping  150.0
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping  150.0
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping  111.5
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping  136.0
# 4  1022.3 -19.4   0.0    N   2.1  Changping  136.0

# %%
#memasukkan kedalam dataframe dongsi
dongsi_df['AQI'] = dongsi_df.apply(calculate_aqi, axis=1)
dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10        SO2        NO2           CO  \
# 0   1  2013      3    1     0    9.0   9.0   3.000000  17.000000   300.000000
# 1   2  2013      3    1     1    4.0   4.0   3.000000  16.000000   300.000000
# 2   3  2013      3    1     2    7.0   7.0  18.531107  17.000000   300.000000
# 3   4  2013      3    1     3    3.0   3.0   5.000000  18.000000  1330.069131
# 4   5  2013      3    1     4    3.0   3.0   7.000000  53.699443   200.000000
#
#           O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station         AQI
# 0  89.000000  -0.5  1024.5 -21.4   0.0  NNW   5.7  Dongsi  158.736842
# 1  88.000000  -0.7  1025.1 -22.1   0.0   NW   3.9  Dongsi  156.157895
# 2  60.000000  -1.2  1025.3 -24.6   0.0  NNW   5.3  Dongsi   74.210526
# 3  57.210637  -1.4  1026.2 -25.5   0.0    N   4.9  Dongsi   67.016906
# 4  84.000000  -1.9  1027.1 -24.5   0.0  NNW   3.2  Dongsi  500.000000

# %%
#membuat kategori berdasarkan panduan aqi
aqi_categories = {
    (0, 50): 'Good',
    (51, 100): 'Moderate',
    (101, 150): 'Unhealthy for Sensitive Groups',
    (151, 200): 'Unhealthy',
    (201, 300): 'Very Unhealthy',
    (301, 500): 'Hazardous'
}

# %%
#fungsi untuk mengelompokkan berdasarkan kategori aqi
def get_aqi_category(aqi):
    for (low_aqi, high_aqi), category in aqi_categories.items():
        if low_aqi <= aqi <= high_aqi:
            return category
    return 'Hazardous'

# %% [markdown]
# panduan membuat kode pemrogaman untuk pengkategorian aqi didapat dari [https://medium.com](/dare-to-be-better/case-study-4-a-step-by-step-guide-to-analyzing-the-aqi-air-quality-index-778c14b0dcfc) dan disesuaikan menggunakan pedoman dari [https://www.airnow.gov](/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf)

# %%
#memasukkan kedalam data
aotizhongxin_df['AQI_Category'] = aotizhongxin_df['AQI'].apply(get_aqi_category)
aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station    AQI  \
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin  122.0
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin  122.0
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin  108.0
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin  104.5
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin  104.5
#
#                      AQI_Category
# 0  Unhealthy for Sensitive Groups
# 1  Unhealthy for Sensitive Groups
# 2  Unhealthy for Sensitive Groups
# 3  Unhealthy for Sensitive Groups
# ...

# %%
#memasukkan kedalam data
changpin_df['AQI_Category'] = changpin_df['AQI'].apply(get_aqi_category)
changpin_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station    AQI  \
# 0  1020.8 -19.7   0.0    E   0.5  Changping  150.0
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping  150.0
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping  111.5
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping  136.0
# 4  1022.3 -19.4   0.0    N   2.1  Changping  136.0
#
#                      AQI_Category
# 0  Unhealthy for Sensitive Groups
# 1  Unhealthy for Sensitive Groups
# 2  Unhealthy for Sensitive Groups
# 3  Unhealthy for Sensitive Groups
# 4  Unhealthy for Sensitive Groups

# %%
#memasukkan kedalam data
dongsi_df['AQI_Category'] = dongsi_df['AQI'].apply(get_aqi_category)
dongsi_df.head()
# Out:
#    No  year  month  day  hour  PM2_5  PM10        SO2        NO2           CO  \
# 0   1  2013      3    1     0    9.0   9.0   3.000000  17.000000   300.000000
# 1   2  2013      3    1     1    4.0   4.0   3.000000  16.000000   300.000000
# 2   3  2013      3    1     2    7.0   7.0  18.531107  17.000000   300.000000
# 3   4  2013      3    1     3    3.0   3.0   5.000000  18.000000  1330.069131
# 4   5  2013      3    1     4    3.0   3.0   7.000000  53.699443   200.000000
#
#           O3  TEMP    PRES  DEWP  RAIN   wd  WSPM station         AQI  \
# 0  89.000000  -0.5  1024.5 -21.4   0.0  NNW   5.7  Dongsi  158.736842
# 1  88.000000  -0.7  1025.1 -22.1   0.0   NW   3.9  Dongsi  156.157895
# 2  60.000000  -1.2  1025.3 -24.6   0.0  NNW   5.3  Dongsi   74.210526
# 3  57.210637  -1.4  1026.2 -25.5   0.0    N   4.9  Dongsi   67.016906
# 4  84.000000  -1.9  1027.1 -24.5   0.0  NNW   3.2  Dongsi  500.000000
#
#   AQI_Category
# 0    Unhealthy
# 1    Unhealthy
# 2     Moderate
# ...

# %%
#melihat rangkuman statistik
aotizhongxin_df.describe( include= "all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
#melihat rangkuman statistik
changpin_df.describe( include= "all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
#melihat rangkuman statistik
dongsi_df.describe( include= "all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
#bagaimana perkembangan nilai air quality index berdasarkan tingkat polusi udara pada tahun 2013 sampai 2017
#membuat sebuah pivot tabel berisi tahun dan rata rata aqi
aotizhongxin = aotizhongxin_df.groupby(by="year").agg({"AQI":("mean")})
aotizhongxin
# Out:
#              AQI
# year
# 2013  165.727709
# 2014  173.886809
# 2015  178.464658
# 2016  169.034386
# 2017  176.025253

# %%
#membuat sebuah pivot tabel berisi tahun dan rata rata aqi
changpin = changpin_df.groupby(by="year").agg({"AQI":( "mean")})
changpin
# Out:
#              AQI
# year
# 2013  162.453464
# 2014  170.843006
# 2015  160.132727
# 2016  148.022725
# 2017  144.029067

# %%
#membuat sebuah pivot tabel berisi tahun dan rata rata aqi
dongsi = dongsi_df.groupby(by="year").agg({"AQI":( "mean")})
dongsi
# Out:
#              AQI
# year
# 2013  182.324050
# 2014  213.105888
# 2015  174.753067
# 2016  179.726360
# 2017  170.528638

# %%
#membuat tabel gabungan 
merge_12 = pd.merge(left = aotizhongxin, right = changpin, how = "outer", left_on = "year", right_on = "year")
merge_12
# Out:
#            AQI_x       AQI_y
# year
# 2013  165.727709  162.453464
# 2014  173.886809  170.843006
# 2015  178.464658  160.132727
# 2016  169.034386  148.022725
# 2017  176.025253  144.029067

# %%
merge_all = pd.merge(left = merge_12, right = dongsi, how = "outer", left_on = "year", right_on = "year")
merge_all
# Out:
#            AQI_x       AQI_y         AQI
# year
# 2013  165.727709  162.453464  182.324050
# 2014  173.886809  170.843006  213.105888
# 2015  178.464658  160.132727  174.753067
# 2016  169.034386  148.022725  179.726360
# 2017  176.025253  144.029067  170.528638

# %%
#membuat line chart
merge_all['year'] = range(2013, 2013 + len(merge_all))
plt.figure(figsize=(15, 8))
plt.plot(np.asarray(merge_all['year']).astype(str), merge_all['AQI_x'], color='blue', label='Kota AotiZhongxin')
plt.plot(np.asarray(merge_all['year']).astype(str), merge_all['AQI_y'], color='green', label='Kota Chanping')
plt.plot(np.asarray(merge_all['year']).astype(str), merge_all['AQI'], color='red', label='Kota Dongsi')
plt.xlabel('Tahun',size=15)
plt.ylabel('Air Quality Index',size=15)
plt.title("Indeks kualitas udara selama tahun 2013-2017", size=20)
plt.legend()

# %% [markdown]
# `np.asarray(merge_all['year']).astype(str)` digunakan untuk mencegah matplotlib menampilkan tahun dalam bentuk desimal (2013.5)

# %%
merge_all_categories = merge_all['AQI'].apply(get_aqi_category)
merge_all_categories
# Out:
# year
# 2013         Unhealthy
# 2014    Very Unhealthy
# 2015         Unhealthy
# 2016         Unhealthy
# 2017         Unhealthy
# Name: AQI, dtype: object

# %% [markdown]
# ### Pertanyaan 2:

# %%
#membuat distribusi mengenai kategori aqi rata rata setiap bulan
aotizhongxin_month= aotizhongxin_df.groupby(by="month").agg({"AQI":("mean")})
changpin_month= changpin_df.groupby(by="month").agg({"AQI":("mean")})
dongsi_month= dongsi_df.groupby(by="month").agg({"AQI":("mean")})

# %%
#menyatukan tabel
merge_21 = pd.merge(left = aotizhongxin_month, right = changpin_month, how = "outer", left_on = "month", right_on = "month")
merge_all_month = pd.merge(left = merge_21, right = dongsi_month, how = "outer", left_on = "month", right_on = "month")
merge_all_month
# Out:
#             AQI_x       AQI_y         AQI
# month
# 1      162.495285  152.406119  200.057830
# 2      166.329717  149.418807  230.070866
# 3      176.707576  163.025126  183.449638
# 4      172.773836  166.256413  182.689371
# 5      184.324884  170.972004  194.413637
# 6      191.178836  179.585671  205.756758
# 7      192.576497  178.585564  206.298094
# 8      173.146007  163.829504  180.091708
# 9      150.608015  139.003434  159.533091
# 10     156.873121  146.040650  163.192683
# 11     166.776350  150.596745  167.059228
# 12     171.758378  154.605050  174.093939

# %%
#membuat line chart
merge_all_month['month'] = range(1, 1 + len(merge_all_month))
plt.figure(figsize=(15, 8))
plt.plot(np.asarray(merge_all_month['month']).astype(str), merge_all_month['AQI_x'], color='blue', label='Kota AotiZhongxin')
plt.plot(np.asarray(merge_all_month['month']).astype(str), merge_all_month['AQI_y'], color='green', label='Kota Chanping')
plt.plot(np.asarray(merge_all_month['month']).astype(str), merge_all_month['AQI'], color='red', label='Kota Dongsi')
plt.xlabel('bulan',size=15)
plt.ylabel('Air Quality Index',size=15)
plt.title("Indeks kualitas udara berdasarkan bulan", size=20)
plt.legend()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclution pertanyaan 1 <br>
#  dari grafik yang dihasilkan dapat diketahui bahwa nilai kualitas udara bervariasi sepanjang tahun dengan nilai terburuk terjadi pada tahun 2014 dengan kategori unhealthy. nilai tersebut kemudian menurun ditahun tahun setelahnya. dapat diketahui pula bahwa stasiun Aothizhongsin memiliki kualitas udara yang paling buruk dan stasiun kota changpin memiliki kualitas udara yang paling baik
#
# - Conclution pertanyaan 2 <br>
#     dari grafik yang dihasilkan  dapat diisimpulkan bahwa tingkat polusi udara tertinggi terjadi pada bulan 6-7 (musim panas) dan nilai polusi terendah terjadi pada bulan 9 (musim gugur)

# %%
#merge_all.to_csv(r'./dashboard/years.csv')
#merge_all_month.to_csv(r'./dashboard/month.csv')
